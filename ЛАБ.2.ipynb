# %%
Стандарты PEP8: единообразие, наглядность, информативность

1. На каждый уровень отступа используется 4 пробела. Табуляция не рекомендуется. Если при доработке чужого проекта была использована табуляция, следует устранить разнобой в коде и заменить Tab на пробелы.

if sunny:
    print("The sun is shining!")
else:
    pass

Пробелы не ставятся:
- Сразу после открывающей скобки и перед закрывающей: ( x )  —  так не надо.
- Перед скобками при вызове аргумента. Неправильно: arg (1). Правильно: arg(1).
- Перед скобками индекса и среза: dict['step'] = map[i].
- Между именем параметра/аргумента, знаком «=» и значением: min(a=10, b=input).
- Перед запятой, точкой с запятой или двоеточием: 
Неправильно: if x == 4 : print(x , y) ; x , y = y , x 
Правильно: if x == 4: print(x, y); x, y = y, x

Ненужно выравнивать код лишними пробелами!

Всегда окружайте эти бинарные операторы одним пробелом с каждой стороны: присваивания (=, +=, -= и другие), сравнения (==, <, >, !=, <>, <=, >=, in, not in, is, is not), логические (and, or, not)

# %%
2. Комментарии - законченные предложения.

- Если комментарий — фраза или предложение, первое слово должно быть написано с большой буквы, если только это не имя переменной, которая начинается с маленькой буквы.
- Если комментарий короткий, можно опустить точку в конце предложения.
- Всегда исправляйте комментарии, если меняете код!
- Блочные комментарии объясняют следующий за ними участок кода. Выравнивайте их на том же уровне и начинайте каждую строку с # и пробела. Параграфы в блочных комментариях разделяются строкой с одной #

Не комментируйте очевидные вещи, так как это затрудняет чтение кода!

# %%
3. Длина строки - максимум 79 символов.
Предпочтительный способ переноса длинных строк является использование подразумеваемых продолжений строк Python внутри круглых, квадратных и фигурных скобок.

def function(arg_one, arg_two,
             arg_three, arg_four):
    return arg_one

# %%
4. Правила выбора имени для переменных, функций, классов и т.п и стили именования:
- Для функций используется слово или слова в нижнем регистре. Для удобства чтения слова разделяются подчеркиванием: function, my_function
- Для переменных используется одна строчная буква, слово или слова: x, var, my_variable
- В обозначении классов каждое слово начинается с заглавной буквы. Слова не разделяются подчеркиванием: Model, MyClass
- Для методов используется слово или слова в нижнем регистре. Для удобства чтения слова разделяются подчеркиванием: class_method, method

Глобальные переменные именуются по тем же соглашениям, что и функции. Кроме того, глобальные переменные стоит использовать только в пределах одного модуля.
